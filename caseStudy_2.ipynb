# %% [markdown]
# <a href="https://colab.research.google.com/github/Raji-317/EDA/blob/main/caseStudy_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/titanic_train.csv')

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
#yellow lines indicated the null values at that particular column
# Out:
# <Axes: >

# %%
#since for age colums ,replacing the null values with the mean,then
df['Age']=df.Age.fillna(df.Age.mean())

# %%
df.Age.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df.Age.isnull().sum()
# Out:
# np.int64(0)

# %%
df.Age.isnull().count()
#count gives the not null values :so here there are 891 ,so no null values
# Out:
# np.int64(891)

# %%
#now converting a categorical :which is an object .removing the outliers from this dataset from the col emabarked and cabin

# %%
#since it is categorical ,we have to replace with the mode of the data
#[0]- it is used beacuse there are possibilities for two get the more than one mode for the data,they get in the series manner,from that picking the first one
df.Cabin.fillna(df.Cabin.mode()[0],inplace=True)
# Out:
# /tmp/ipykernel_7954/74218858.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Cabin.fillna(df.Cabin.mode()[0],inplace=True)

# %%
df.Cabin.isnull().sum()
# Out:
# np.int64(0)

# %%
df.Cabin.isnull().count()
#null valaues are removed
# Out:
# np.int64(891)

# %%
#now for embarked:so it only contains the 2 null values,we can drop it beacuse it has less null values ..so data dont effect
df.dropna(subset=['Embarked'], inplace=True)

# %%
df.Embarked.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Embarked, Length: 889, dtype: bool

# %%
df.Embarked.isnull().sum()
# Out:
# np.int64(0)

# %%
#here null values are removed by deeting the rows from the datset
df.Embarked.isnull().count()
# Out:
# np.int64(889)

# %%
df.shape
#so two of the rows got deleted from the dataset
# Out:
# (889, 12)

# %%
df.isnull().sum()
#checking whether the null values are present or not
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
#another way for finding null
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
#now finding the outliers for each col
sns.boxplot(df.Age)
plt.show()

# %%
for i in df.columns:
  sns.boxplot(df[i])
  plt.show()
  # it gives the error output  ,becaues boxplot ios only for numeric datatypes not for categorical..so whenever it comes to categories then it gives an error

# %%
for col in df.select_dtypes(include=['int64', 'float64']).columns:
    sns.boxplot(df[col])
    plt.title(col)
    plt.show()

# %%
#here in the cols of Age,Fare,SibSp,Parch have the outliers: so we have to remove teh outliers from these cols

# %%
#now checking how many outliers are there in a fare col
Q1=df['Fare'].quantile(0.25)
Q3=df['Fare'].quantile(0.75)
IQR=Q3-Q1
lower=Q1-1.5*IQR
upper=Q3+1.5*IQR
outliers=df[(df['Fare']<lower) | (df['Fare']>upper)]
print(len(outliers))
# Out:
# 114

# %%
outliers = df[(df['Fare'] < lower) | (df['Fare'] > upper)]

outliers[['Fare', 'Pclass', 'Survived']].head(20)
# Out:
#          Fare  Pclass  Survived
# 1     71.2833       1         1
# 27   263.0000       1         0
# 31   146.5208       1         1
# 34    82.1708       1         0
# 52    76.7292       1         1
# 62    83.4750       1         0
# 72    73.5000       2         0
# 88   263.0000       1         1
# 102   77.2875       1         0
# 118  247.5208       1         0
# 120   73.5000       2         0
# 124   77.2875       1         0
# 139   79.2000       1         0
# 151   66.6000       1         1
# 159   69.5500       3         0
# 180   69.5500       3         0
# 195  146.5208       1         1
# 201   69.5500       3         0
# 215  113.2750       1         1
# 218   76.2917       1         1

# %%
sns.histplot(df['Fare'], kde=True)
plt.show()

# %%
Q1 = df['Age'].quantile(0.25)
Q3 = df['Age'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
outliers = df[(df['Age'] < lower) | (df['Age'] > upper)]
print(outliers.shape)
print(lower)
print(upper)
# Out:
# (65, 12)
# 2.5
# 54.5

# %%
outliers = df[(df['Age'] < lower) | (df['Age'] > upper)]

outliers[['Age', 'Pclass', 'Survived']].head(20)
outliers = df[(df['Age'] < 2.5) | (df['Age'] > 54.5)]

print(outliers.shape[0])
df[(df['Age'] < 2.5) | (df['Age'] > 54.5)]['Age'].sort_values()
df = df[(df['Age'] >= lower) & (df['Age'] <= upper)]
print(df['Age'].min())
print(df['Age'].max())
# Out:
# 65
# 3.0
# 54.0

# %%
sns.boxplot(df.Age)
plt.show()

# %%
df.shape
# Out:
# (824, 12)

# %%
#now analysing the data with respect to the target variables
#here target variable is "Survived" better analysis is Survived with the sex,Pclass,and Age

# %%
sns.countplot(x='Survived',hue='Sex',data=df)
plt.show()

# %%
#we understand that with respect to the sex:male are less percentage of surviving compare to female
#and feamle has more surviving perentage than male
#now with respect to the age

# %%
sns.countplot(x='Survived',hue='Pclass',data=df)
plt.show()

# %%
sns.histplot(data=df, x='Age', hue='Survived', kde=True)
plt.show()

# %%
sns.violinplot(x='Survived', y='Age', data=df)
plt.show()

# %%
sns.histplot(df['Age'], kde=False, color='darkred', bins=40)
plt.show()

# %%
sns.countplot(x='Survived',hue='SibSp',data=df)
plt.show()

# %%
#so a model cannot understands the categorical values..so we have to convert them into numerical which will understands by the  model

# %%
#so ,we are going to apply the one-hot encoding
df1=df.copy()

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked
# 0      0         A/5 21171   7.2500  B96 B98        S
# 1      0          PC 17599  71.2833      C85        C
# 2      0  STON/O2. 3101282   7.9250  B96 B98        S
# 3      0            113803  53.1000     C123        S
# ...

# %%
pd.get_dummies(df['Embarked'], drop_first=True).head()
# Out:
#        Q      S
# 0  False   True
# 1  False  False
# 2  False   True
# 3  False   True
# 4  False   True

# %%
sex=pd.get_dummies(df1['Sex'],drop_first=True)
embark=pd.get_dummies(df1['Embarked'],drop_first=True)

# %%
df.drop(['Sex','Embarked','Name','Ticket'],axis=1,inplace=True, errors='ignore')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare    Cabin
# 0            1         0       3  22.0      1      0   7.2500  B96 B98
# 1            2         1       1  38.0      1      0  71.2833      C85
# 2            3         1       3  26.0      0      0   7.9250  B96 B98
# 3            4         1       1  35.0      1      0  53.1000     C123
# 4            5         0       3  35.0      0      0   8.0500  B96 B98

# %%
df=pd.concat([df,sex,embark],axis=1)
df.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare    Cabin   male  \
# 0            1         0       3  22.0      1      0   7.2500  B96 B98   True
# 1            2         1       1  38.0      1      0  71.2833      C85  False
# 2            3         1       3  26.0      0      0   7.9250  B96 B98  False
# 3            4         1       1  35.0      1      0  53.1000     C123  False
# 4            5         0       3  35.0      0      0   8.0500  B96 B98   True
#
#        Q      S
# 0  False   True
# 1  False  False
# 2  False   True
# 3  False   True
# 4  False   True

# %%
print(df.columns[df.columns.duplicated()])
# Out:
# Index([], dtype='object')

# %%
df = df.loc[:, ~df.columns.duplicated()]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare    Cabin   male  \
# 0            1         0       3  22.0      1      0   7.2500  B96 B98   True
# 1            2         1       1  38.0      1      0  71.2833      C85  False
# 2            3         1       3  26.0      0      0   7.9250  B96 B98  False
# 3            4         1       1  35.0      1      0  53.1000     C123  False
# 4            5         0       3  35.0      0      0   8.0500  B96 B98   True
#
#        Q      S
# 0  False   True
# 1  False  False
# 2  False   True
# 3  False   True
# 4  False   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 824 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  824 non-null    int64
#  1   Survived     824 non-null    int64
#  2   Pclass       824 non-null    int64
#  3   Age          824 non-null    float64
#  4   SibSp        824 non-null    int64
#  5   Parch        824 non-null    int64
#  6   Fare         824 non-null    float64
#  7   Cabin        824 non-null    object
#  8   male         824 non-null    bool
#  9   Q            824 non-null    bool
#  10  S            824 non-null    bool
# dtypes: bool(3), float64(2), int64(5), object(1)
# memory usage: 60.4+ KB

# %%
cabin=pd.get_dummies(df1['Cabin'],drop_first=True)

# %%
df=pd.concat([df,cabin],axis=1)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare    Cabin   male  \
# 0            1         0       3  22.0      1      0   7.2500  B96 B98   True
# 1            2         1       1  38.0      1      0  71.2833      C85  False
# 2            3         1       3  26.0      0      0   7.9250  B96 B98  False
# 3            4         1       1  35.0      1      0  53.1000     C123  False
# 4            5         0       3  35.0      0      0   8.0500  B96 B98   True
#
#        Q  ...     E8  F E69  F G63  F G73     F2    F33    F38     F4     G6  \
# 0  False  ...  False  False  False  False  False  False  False  False  False
# 1  False  ...  False  False  False  False  False  False  False  False  False
# 2  False  ...  False  False  False  False  False  False  False  False  False
# 3  False  ...  False  False  False  False  False  False  False  False  False
# 4  False  ...  False  False  False  False  False  False  False  False  False
#
#        T
# 0  False
# 1  False
# ...

# %%
#Univariate analysis
sns.histplot(df['Age'], kde=True)
plt.show()

# %%
sns.boxplot(x=df['Age'])
plt.show()

# %%
sns.histplot(df['Fare'], kde=True)
#these are the univariate analysis
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
#training and testing of data

# %%
train = df1.drop(['Survived','Cabin','Name','Ticket'], axis=1)
test = df1['Survived']

# %%
train.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1       3    male  22.0      1      0   7.2500        S
# 1            2       1  female  38.0      1      0  71.2833        C
# 2            3       3  female  26.0      0      0   7.9250        S
# 3            4       1  female  35.0      1      0  53.1000        S
# 4            5       3    male  35.0      0      0   8.0500        S

# %%
print(train.shape)
# Out:
# (824, 8)

# %%
test.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    train,
    test,
    test_size=0.2,
    random_state=42
) # Regenerating X_train, X_test, y_train, y_test

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (659, 135)
# (165, 135)
# (659,)
# (165,)

# %%
#Training a model

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)

model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000)

# %%
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8121212121212121

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 659 entries, 261 to 112
# Columns: 135 entries, PassengerId to T
# dtypes: bool(129), float64(2), int64(4)
# memory usage: 119.1 KB

# %%
prediction=model.predict(X_test)

# %%
accuracy_score(y_test, prediction)
# Out:
# 0.8121212121212121

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85        97
#            1       0.80      0.72      0.76        68
#
#     accuracy                           0.81       165
#    macro avg       0.81      0.80      0.80       165
# weighted avg       0.81      0.81      0.81       165

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, y_pred))
# Out:
# [[85 12]
#  [19 49]]

# %%
print(model)
print(model.score(X_test, y_test))
X_train.shape
# Out:
# LogisticRegression(max_iter=1000)
# 0.8121212121212121
# (659, 135)

# %%
X_test.shape
# Out:
# (165, 135)
